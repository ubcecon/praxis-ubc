# %% [markdown]
# # Introduction to Convolutional Neural Networks (CNNs)
#
# Praxis UBC Team
# _Kaiyan Zhang_
#
# 2025-07-24
#
#
# <meta http-equiv="refresh" content="0; url=intro_to_cnn.html">
#
# If you are not redirected automatically, [click here to view the Intro to CNN's Notebook](intro_to_cnn.html).

# %% [markdown]
# # Embedding Driven Text Analysis of Crease's Stance Towards Chinese Immigrants
#
# prAxIs UBC Team
# _Kaiyan Zhang, Irene Berezin, Alex Ronczewski_
#
# 2025-08-04
#
#
# <meta http-equiv="refresh" content="0; url=text_embeddings_workshop.html">
#
# If you are not redirected automatically, [click here to view the Text Embedding Workshop Notebook](text_embeddings_workshop.html).

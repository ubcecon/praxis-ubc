# %% [markdown]
# # Network Analysis: KINMATRIX Dataset
#
# prAxIs UBC Team
# _Alex Ronczewski_
#
# 2025-08-24
#
#
# <meta http-equiv="refresh" content="0; url=kinmatrix.html">
#
# If you are not redirected automatically, [click here to view the KINMATRIX notebook](kinmatrix.html).

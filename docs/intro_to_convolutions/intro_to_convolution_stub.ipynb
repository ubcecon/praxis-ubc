# %% [markdown]
# # Introduction to Convolutions
#
# prAxIs UBC Team
# _Kaiyan Zhang_
#
# 2025-07-22
#
#
#
# <meta http-equiv="refresh" content="0; url=intro_to_convolution.html">
#
# If you are not redirected automatically, [click here to view the Intro to Convolutions Notebook](intro_to_convolution.html).

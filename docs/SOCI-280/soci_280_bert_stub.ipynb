# %% [markdown]
# # Introduction to Sentiment Analysis: Identifying and Mapping Disinformation Campaigns using NLP
#
# _Irene Berezin, Anna Kovtunenko, Jalen Faddick_, 2025-07-24
#
#
# <meta http-equiv="refresh" content="0; url=soci_280_bert.html">
#
# If you are not redirected automatically, [click here to view the SOCI 280 notebook](soci_280_bert.html).

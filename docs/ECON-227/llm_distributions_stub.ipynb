# %% [markdown]
# # How Do Large Language Models Predict?
#
# prAxIs UBC Team
# _Krishaant Pathmananathan, Yash Mali, Kaiyan Zhang_
#
# 2025-08-26
#
#
# <meta http-equiv="refresh" content="0; url=llm_distributions.html">
#
# If you are not redirected automatically, [click here to view the ECON 227 Notebook](llm_distributions.html).

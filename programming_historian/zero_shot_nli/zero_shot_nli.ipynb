# %% [markdown]
# # Zero-Shot Natural Language Inference with Historical Legal Texts

# %% [markdown]
# ### Contents

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Lesson Overview

# %% [markdown]
# ### Learning Outcomes

# %% [markdown]
# ### Suggested Prior Skills

# %% [markdown]
# ### Lesson Setup
#
# #### Setting up Google Colab

# %% [markdown]
# #### Setting up Local Environment

# %% [markdown]
# ### OCR and Text Cleaning

# %% [markdown]
# ### Fundamentals of Natural Language Inference

# %% [markdown]
# ### Zero-Shot Classification with Pre-trained Models

# %% [markdown]
# ### Prompt Engineering for NLI

# %% [markdown]
# ### Interpretation of Results

# %% [markdown]
# ### Conclusions and Next Steps

# %% [markdown]
# ### Endnotes
